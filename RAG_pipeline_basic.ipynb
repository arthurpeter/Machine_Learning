# %% [markdown]
# <a href="https://colab.research.google.com/github/arthurpeter/Machine_Learning/blob/main/RAG_pipeline_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import xml.etree.ElementTree as ET
from pathlib import Path
from typing import List, Optional, Union

# Pentru a permite type hinting cu 'Node' în interiorul definiției clasei
from __future__ import annotations

class Node:
    """
    Reprezintă un nod într-o structură de arbore, similar cu un element XML.

    Atribute:
        label (str): Eticheta nodului (de ex., tag-ul XML).
        content (str): Conținutul text al nodului.
        children (List[Node]): O listă a nodurilor copil.
    """

    def __init__(self, label: str = "", content: str = ""):
        """Inițializează un nod nou."""
        self.label: str = label
        self.content: str = content
        self.children: List[Node] = []

    def print_node(self, level: int = 0):
        """
        Afișează structura arborelui începând de la acest nod,
        cu indentare pentru vizualizare.
        """
        indent = "  " * level
        if not self.children:
            print(f"{indent}Level {level} - Label: {self.label}, Content: {self.content}")
        else:
            print(f"{indent}Level {level} - Label: {self.label}, Content: {self.content}")
            for child in self.children:
                child.print_node(level + 1)

    @staticmethod
    def generate_tree_from_xml(xml_string: str) -> Optional[Node]:
        """
        Generează un arbore de noduri 'Node' dintr-un string XML.

        Args:
            xml_string: String-ul care conține XML-ul.

        Returns:
            Nodul rădăcină al arborelui sau None dacă parsarea eșuează.
        """
        try:
            # Parsează string-ul XML
            root_element = ET.fromstring(xml_string)
            # Începe construcția recursivă a arborelui
            return Node._build_node(root_element)
        except ET.ParseError as e:
            print(f"Eroare la parsarea XML: {e}")
            return None

    @staticmethod
    def _build_node(element: ET.Element) -> Node:
        """
        Metodă ajutătoare recursivă pentru a construi arborele
        din elemente XML (din ElementTree).
        """
        node = Node()
        # Setează eticheta (label) ca fiind tag-ul elementului XML
        node.label = element.tag

        # Setează conținutul ca fiind textul din interiorul elementului
        # .strip() curăță spațiile albe de la început și sfârșit
        if element.text:
            node.content = element.text.strip()
        else:
            node.content = "" # Potrivește logica Java (conținut gol vs. None)

        # Construiește recursiv copiii
        for child_element in element:
            node.children.append(Node._build_node(child_element))

        return node

    def get_content(self) -> str:
        """
        Returnează o reprezentare sub formă de string a nodului și
        a sub-arborelui său, recursiv.

        Format: "label: content" (pentru frunze)
        Format: "label: [child1_content]; [child2_content]" (pentru noduri cu copii)
        """
        result = []
        if not self.children:
            # Este un nod frunză (fără copii)
            content_str = self.content if self.content else ""
            result.append(f"{self.label}: {content_str}")
        else:
            # Este un nod părinte
            # Colectează recursiv conținutul de la toți copiii
            child_contents = [child.get_content() for child in self.children]
            # Unește conținutul copiilor cu "; "
            joined_content = "; ".join(child_contents)
            result.append(f"{self.label}: {joined_content}")

        return "".join(result)

    def get_split_content(self, max_length: int) -> List[str]:
        """
        Preia conținutul fiecărui copil DIRECT și îl returnează ca
        o listă, doar dacă NICIUN copil nu depășește max_length.

        Dacă un singur copil depășește limita, returnează o listă goală.
        """
        parts = []
        for child in self.children:
            child_content = child.get_content()
            if len(child_content) > max_length:
                # Un copil depășește limita, returnăm o listă goală
                # (conform logicii Java)
                return []
            parts.append(child_content)

        # Toți copiii au fost sub limită
        return parts


# --- Execuție principală (echivalentul 'public static void main') ---

if __name__ == "__main__":
    with open("response.xml", "r") as f:
      xml = f.read()


    # Exemplu de citire din fișier (dacă ai nevoie)
    # Decomentează liniile de mai jos și comentează linia de mai sus
    # pentru a citi din fișierul specificat.

    # xml_file_path_str = "C:/Users/arthurp/Documents/Work/MCP/api_wrapper/src/main/java/dvh/mcp/api_wrapper/dto/response.xml"
    # xml_file_path = Path(xml_file_path_str)
    #
    # try:
    #     # Citim conținutul fișierului
    #     xml_data_din_prompt = xml_file_path.read_text(encoding="utf-8")
    # except FileNotFoundError:
    #     print(f"EROARE: Fișierul nu a fost găsit la calea: {xml_file_path}")
    #     exit()
    # except Exception as e:
    #     print(f"EROARE la citirea fișierului: {e}")
    #     exit()


    # 1. Generează arborele din string-ul XML
    tree = Node.generate_tree_from_xml(xml)

    if tree:
        # --- O poți folosi pentru debug, ca în Java ---
        # print("--- Structura Arborelui ---")
        # tree.print_node()
        # print("-" * 30)

        # --- Poți vedea conținutul complet, recursiv ---
        # print("\n--- Conținut Complet (Recursiv) ---")
        # print(tree.get_content())
        # print("-" * 30)

        # 2. Execută logica din 'main' (getSplitContent pe nodul rădăcină)
        print("\n--- Conținut Împărțit (pe copiii rădăcinii) ---")
        # Folosim o limită foarte mare, ca în exemplul tău
        contents = tree.get_split_content(100000)

        # 3. Afișează rezultatele
        for content in contents:
            print(content, "\n\n") # Adăugăm linii goale ca în Java

        print(f"Număr total de elemente (copii ai rădăcinii): {len(contents)}")
# Out:
# --- Conținut Împărțit (pe copiii rădăcinii) ---
# row: RowNo: 1; IdCommand: 21851285; DataDocument: 2021-02-01; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2021-02011021152972-VUJ; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: MERCEDES-BENZ AMG; AnFabricatie: 2019; SerieSasiu: WDB4632761X336354; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNUL ESTE PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FACE OBIECTUL CONTRACTULUI DE LEASING NR. 65002 DIN DATA DE 08.05.2020.
#
#
# row: RowNo: 2; IdCommand: 21851285; DataDocument: 2021-04-08; Creditors: PF: -PJ: CEC BANK SUCURSALA GARA DE NORD;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: AD REGESTA SA - BUCURESTI; IdentificatorInscriere: 2021-04081206389291-IVK; DescriereBunuri: AlteBunuri: CountCategorie: 2; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 2; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 0; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Cont bancar; IdentificareBun: RO17CECEB00030RON0584884; DescriereSuplimentara: CONT DESCHIS LA CEC BANK S.A.; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 2; Categorie: Cont bancar; IdentificareBun: RO33CECEC001946009256231; DescriereSuplimentara: CONT DESCHIS LA CEC BANK S.A.; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: IPOTECA MOBILIARA ASUPRA CONTURILOR BANCARE PREZENTE, CAT SI A ORICAROR CONTURI VIITOARE, PRECUM SI ASUPRA TUTUROR DREPTURILOR CU PRIVIRE SUMELE EXISTENTE IN ACESTE CONTURI, PENTRU GARANTAREA PLATII SI DESCARCARII IN INTREGIME A OBLIGATIILOR PANA LA CONCURENTA SUMEI PRINCIPALE IMPRUMUTATE IN VALOARE DE 4.100.000 LEI (PATRUMILIOANEOSUTAMIILEI), PLUS DOBANZILE, DOBANZILE PENALIZATOARE, COSTURILE SI SPEZELE BANCARE AFERENTE PRECUM SI A ORICAROR ALTE SUME DATORATE SAU POTENTIAL DATORATE BANCII IN BAZA CONTRACTULUI DE CREDIT NR. RQ20036120047674 DIN DATA 08.04.2020 (CU MODIFICARILE ULTERIOARE) (�CONTRACTUL DE CREDIT�), INCHEIAT INTRE STRABENBAU LOGISTIC SRL IN CALITATE DE IMPRUMUTAT SI BANCA.
#
#
# row: RowNo: 3; IdCommand: 21851285; DataDocument: 2021-06-02; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2021-06021206012305-UVH; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: MERCEDES BENZ ACROCS 5; AnFabricatie: 2020; SerieSasiu: W1T96423110493468; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; row: NumarOrdine: 2; Model: MERCEDES BENZ AROCS 5; AnFabricatie: 2020; SerieSasiu: W1T96423110493469; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNURILE SUNT PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FAC OBIECTUL CONTRACTULUI DE LEASING NR. 67036 DIN DATA DE 24.02.2021.
#
#
# row: RowNo: 4; IdCommand: 21851285; DataDocument: 2021-07-08; Creditors: PF: -PJ: OTP LEASING ROMANIA IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: CABINET DE AVOCAT NUCA PAUL CRISTIAN; IdentificatorInscriere: 2021-07081021209679-QMC; DescriereBunuri: AlteBunuri: CountCategorie: 1; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 0; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 1; row: NumarOrdine: 1; Categorie: Utilaje agricole, altele decat autovehicule; IdentificareBun: TRACTOR DF 6205 RC-SH STAGE V, SERIE WSXFL00200LD10084; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNUL ESTE PROPRIETATEA CREDITORULUI OTP LEASING ROMANIA IFN S.A.
#
#
# row: RowNo: 5; IdCommand: 21851285; DataDocument: 2021-10-26; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2021-10260912349427-OMF; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: MERCEDES BENZ AROCS; AnFabricatie: 2021; SerieSasiu: W1T96442610528808; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNUL ESTE PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FACE OBIECTUL CONTRACTULUI DE LEASING NR. 68045 DIN DATA DE 20.05.2021.
#
#
# row: RowNo: 6; IdCommand: 21851285; DataDocument: 2021-10-27; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2021-10271548309108-CBC; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: MERCEDES-BENZ AROCS; AnFabricatie: 2021; SerieSasiu: W1T96400310533022; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNUL ESTE PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FACE OBIECTUL CONTRACTULUI DE LEASING NR. 68046 DIN DATA DE 20.05.2021.
#
#
# row: RowNo: 7; IdCommand: 21851285; DataDocument: 2021-10-27; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2021-10271604049435-GNS; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: MERCEDES BENZ AROCS; AnFabricatie: 2020; SerieSasiu: W1T96433110448240; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; row: NumarOrdine: 2; Model: MERCEDES BENZ AROCS; AnFabricatie: 2020; SerieSasiu: W1T96433110450350; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNURILE SUNT PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FAC OBIECTUL CONTRACTULUI DE LEASING NR. 68732 DIN DATA DE 16.07.2021.
#
#
# row: RowNo: 8; IdCommand: 21851285; DataDocument: 2021-10-27; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2021-10271654299031-LHN; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: MERCEDES BENZ AROCS; AnFabricatie: 2020; SerieSasiu: W1T96423110491308; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; row: NumarOrdine: 2; Model: MERCEDES BENZ AROCS; AnFabricatie: 2020; SerieSasiu: W1T96423110490951; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNURILE SUNT PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FAC OBIECTUL CONTRACTULUI DE LEASING NR. 69202 DIN DATA DE 25.08.2021.
#
#
# row: RowNo: 9; IdCommand: 21851285; DataDocument: 2021-10-27; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2021-10271656509049-WJQ; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: MERCEDES BENZ AROCS; AnFabricatie: 2021; SerieSasiu: W1T96433110501527; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; row: NumarOrdine: 2; Model: MERCEDES BENZ AROCS; AnFabricatie: 2021; SerieSasiu: W1T96433110501243; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; row: NumarOrdine: 3; Model: MERCEDES BENZ AROCS; AnFabricatie: 2021; SerieSasiu: W1T96423110482994; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNURILE SUNT PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FAC OBIECTUL CONTRACTULUI DE LEASING NR. 69206 DIN DATA DE 26.08.2021.
#
#
# row: RowNo: 10; IdCommand: 21851285; DataDocument: 2021-10-28; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2021-10280919119665-FYD; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: MERCEDES BENZ AROCS; AnFabricatie: 2020; SerieSasiu: W1T96423110492030; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; row: NumarOrdine: 2; Model: MERCEDES BENZ AROCS; AnFabricatie: 2020; SerieSasiu: W1T96423110492031; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; row: NumarOrdine: 3; Model: MERCEDES BENZ AROCS; AnFabricatie: 2020; SerieSasiu: W1T96423110493471; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNURILE SUNT PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FAC OBIECTUL CONTRACTULUI DE LEASING NR. 69810 DIN DATA DE 08.10.2021.
#
#
# row: RowNo: 11; IdCommand: 21851285; DataDocument: 2021-11-17; Creditors: PF: -PJ: BANCA ROMANA DE CREDITE SI INVESTITII;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ;; UtilizatorAutorizat: CABINET DE AVOCAT BARA A. CIPRIAN; IdentificatorInscriere: 2021-11170958519993-YLB; DescriereBunuri: AlteBunuri: CountCategorie: 2; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 1; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 1; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Creante conf. art. 2389 lit. a) si b) din Codul civil; IdentificareBun: SOLDURILE CREDITOARE PREZENTE SI VIITOARE IN LEI SI IN VALUTA ALE CONTURILOR BANCARE ALE GARANTULUI IDENTIFICATE MAI JOS IN PREZENTUL AVIZ, PRECUM SI ASUPRA TUTUROR DREPTURILOR CU PRIVIRE LA ACESTE SUME, INCLUSIV ASUPRA TUTUROR PRODUSELOR ACESTORA.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 2; Categorie: Cont bancar; IdentificareBun: RO25MIND000100331181RO01; DescriereSuplimentara: MONEDA RON; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: GARANTUL CONSTITUIE IN FAVOAREA BANCII IN MOD IREVOCABIL SI NECONDITIONAT O IPOTECA MOBILIARA ASUPRA ACTIVELOR GREVATE INSEMNAND CONTURILE BANCARE SI SOLDURILE CREDITOARE ALE ACESTORA IDENTIFICATE MAI JOS, PENTRU GARANTAREA PLATII SI INDEPLINIRII TUTUROR OBLIGATIILOR GARANTATE PANA LA CONCURENTA PRINCIPALULUI IMPRUMUTAT DE 2.200.000 RON (douamilioanedouasutemiilei)  PLUS DOBANZILE, DOBANZILE PENALIZATOARE, COSTURILE SI SPEZELE BANCARE AFERENTE PRECUM SI A ORICAROR ALTE SUME DATORATE SAU POTENTIAL DATORATE BANCII IN BAZA CONTRACTULUI DE ACORDARE A UNEI FACILITATI DE CREDIT NR. 40  INCHEIAT LA DATA DE 16.11.2021 , INCLUSIV TAXELE SI IMPOZITELE SI ORICE ALTE COSTURI SI CHELTUIELI INREGISTRATE DE BANCA PENTRU PASTRAREA, RECUPERAREA SI/SAU EXECUTAREA ORICAREI PARTI A IPOTECII CONSTITUITE IN CONFORMITATE CU CONTRACTUL DE IPOTECA. IPOTECA ESTE CONSTITUITA SI MENTINUTA PENTRU GARANTAREA ORICAREIA DINTRE OBLIGATIILE GARANTATE SI ASUMATE IN BAZA CONTRACTULUI DE CREDIT SI A CONTRACTULUI DE IPOTECA.
#
#
# row: RowNo: 12; IdCommand: 21851285; DataDocument: 2021-12-10; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2021-12101340389767-RSU; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: MERCEDES BENZ AROCS; AnFabricatie: 2020; SerieSasiu: W1T96423110493471; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; row: NumarOrdine: 2; Model: MERCEDES BENZ AROCS; AnFabricatie: 2020; SerieSasiu: W1T96423110492030; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; row: NumarOrdine: 3; Model: MERCEDES BENZ AROCS; AnFabricatie: 2020; SerieSasiu: W1T96423110492031; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNURILE SUNT PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FAC OBIECTUL CONTRACTULUI DE LEASING NR. 69810 DIN DATA DE 08.10.2021.
#
#
# row: RowNo: 13; IdCommand: 21851285; DataDocument: 2022-02-02; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2022-02021339279348-REU; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: JCB BULDOEXCAVATOR MODEL 3CX14MFWM; AnFabricatie: 2020; SerieSasiu: JCB3CX4TLL2871004; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; row: NumarOrdine: 2; Model: JCB BULDOEXCAVATOR MODEL 3CX14MFWM; AnFabricatie: 2019; SerieSasiu: JCB3CX4TCK2826079; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; row: NumarOrdine: 3; Model: JCB BULDOEXCAVATOR MODEL 3CX14M; AnFabricatie: 2021; SerieSasiu: JCB3CX4TKL2873568; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNURILE SUNT PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FAC OBIECTUL CONTRACTULUI DE LEASING NR. 70334 DIN DATA DE 19.11.2021.
#
#
# row: RowNo: 14; IdCommand: 21851285; DataDocument: 2022-02-25; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2022-02250947319475-PVR; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: MERCEDES BENZ ATEGO; AnFabricatie: 2020; SerieSasiu: W1T96720110494445; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNUL ESTE PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FACE OBIECTUL CONTRACTULUI DE LEASING NR. 70815 DIN DATA DE 30.12.2021.
#
#
# row: RowNo: 15; IdCommand: 21851285; DataDocument: 2022-03-10; Creditors: PF: -PJ: ARABESQUE SRL � PUNCT DE LUCRU PLOIESTI;; Debitors: PF: -PJ: STRABENBAU LOGISTIC SRL;; UtilizatorAutorizat: CABINET DE AVOCAT MORAR GABRIELA MARIA; IdentificatorInscriere: 2022-03101118179697-VVL; DescriereBunuri: AlteBunuri: CountCategorie: 3; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 1; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 0; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 1; Recolte: 0; Universalitati: 1; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Polite de asigurare; IdentificareBun: CESIONAREA TUTUROR DREPTURILOR DE DESPAGUBIRE PROVENIND DIN POLITA DE ASIGURARE A BUNURILOR DESCRISE, CARE FACE OBIECTUL IPOTECII .; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 2; Categorie: Universalitati; IdentificareBun: BUNURILE ACHIZITIONATE DE DEBITOR/CONSTITUITOR IN TEMEIUL CONTRACTULUI DE VANZARE�CUMPARARE, REPREZENTAND PRODUSE DIN GAMA MATERIALELOR DE CONSTRUCTII, FINISAJE, INSTALATII SI ELECTRICE COMERCIALIZATE DE CREDITOR SI ASUPRA CARORA CREDITORUL ARE UN DREPT GARANTAT POTRIVIT CLAUZEI DE REZERVA A PROPRIETATII DIN CONTRACT.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 3; Categorie: Alte bunuri; IdentificareBun: IPOTECA SE EXTINDE AUTOMAT, PRIN EFECTUL LEGII, ASUPRA  BUNURILOR CARE INLOCUIESC BUNURILE IPOTECATE, ASUPRA BUNURILOR IN CARE A TRECUT VALOAREA BUNURILOR IPOTECATE PRECUM SI ASUPRA TUTUROR FRUCTELOR SI PRODUCTELOR REZULTATE DIN ORICE FORMA DE ADMINISTRARE, DE EXPLOATARE  SAU DE DISPOZITIE INTREPRINSE DE DEBITOR/CONSTITUITOR ASUPRA BUNURILOR CE FAC OBIECTUL  PREZENTEI IPOTECI.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: IPOTECA MOBILIARA CONSTITUITA IN SCOPUL GARANTARII SI ASIGURARII BUNEI EXECUTARI A OBLIGATIILOR CONTRACTUALE PRINCIPALE SI ACCESORII, PROVENIND DIN CONTRACTUL DE VANZARE CUMPARARE NR. 847/01.03.2022 SI ACTELE ADITIONALE CU MODIFICARI SI COMPLETARI ULTERIOARE, PRECUM SI DIN FACTURILE FISCALE EMISE DE CREDITOR SI EVIDENTIATE IN FISA DE CONT A CLIENTULUI DEBITOR. PREZENTA GARANTIE CONSTITUITA IN FAVOAREA CREDITORULUI IN TEMEIUL CONTRACTULUI MENTIONAT SI A ACTELOR ADITIONALE INCHEIATE LA ACESTA, VA RAMANE IN VIGOARE PANA LA INDEPLINIREA INTEGRALA DE CATRE DEBITOR A OBLIGATIILOR PRINCIPALE SI ACCESORII, GARANTATE CREDITORULUI.
#
#
# row: RowNo: 16; IdCommand: 21851285; DataDocument: 2022-04-15; Creditors: PF: -PJ: TIRIAC LEASING IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ; TIRIAC LEASING IFN;; UtilizatorAutorizat: Alina Calborean - Birou Individual Notarial; IdentificatorInscriere: 2022-04150844489136-LAH; DescriereBunuri: BunuriAutovehicule: row: NumarOrdine: 1; Model: INCARCATOR FRONTAL TELESCOPIC; AnFabricatie: 2019; SerieSasiu: JCB5RAAEKK2786181; SerieMotor: ; NrDeInmatriculare: ; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #2; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: BUNUL ESTE PROPRIETATEA CREDITORULUI TIRIAC LEASING IFN SA SI FACE OBIECTUL CONTRACTULUI DE LEASING NR. 71041 DIN DATA DE 27.01.2022.
#
#
# row: RowNo: 17; IdCommand: 21851285; DataDocument: 2022-10-31; Creditors: PF: -PJ: RoCredit IFN Baia Mare sucursala Bucuresti;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: CABINET DE AVOCAT CALIN HERTA; IdentificatorInscriere: 2022-10311420119494-YIC; DescriereBunuri: AlteBunuri: CountCategorie: 3; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 2; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 1; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Creante conf. art. 2389 lit. a) si b) din Codul civil; IdentificareBun: Contract de cesiune de creanta NR. 539C din 31/10/2022 a creantelor provenite din CONTRACT SUBSECVENT DE LUCRARI NR. 332 din data de 23.08.2022 inregistrat la C.N.A.I.R. SA prin D.R.D.P. BUCURESTI sub nr.4E/179767 din data de 23.08.2022 incheiat intre CEDENT si DEBITORUL CEDAT,cu actele aditionale prezente si viitoare; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1;Tert persoana juridica #COMPANIA NATIONALA DE ADMINISTRARE A INFRASTRUCTURII RUTIERE SA � PRIN DIRECTIA REGIONALA DE DRUMURI SI PODURI BUCURESTIsocietate pe actiuniBd. Dinicu Golescu nr. 38J40/552/2004160543681RomaniaBucurestiSECTOR 1fals; row: NumarOrdine: 2; Categorie: Creante conf. art. 2389 lit. a) si b) din Codul civil; IdentificareBun: Factura seria STB nr. 20221435 din data de 24.10.2022 in suma de 3.946.230,00 lei scadenta in data de 23.12.2022 emisa de STRABENBAU LOGISTIC SRL pentru C.N.A.I.R. SA PRIN D.R.D.P.  BUCURESTI; DescriereSuplimentara: CONTRACT DE CESIUNE DE CREANTA NR. 540 din 31/10/2022 prin care se cesioneaza creanta in suma de 3.946.230,00 lei provenita din Factura fiscala mai sus mentionata pe care cedentul o are asupra debitorului cedat.; AlteInformatii: Constituitor persoana juridica #1;Tert persoana juridica #COMPANIA NATIONALA DE ADMINISTRARE A INFRASTRUCTURII RUTIERE SA � PRIN DIRECTIA REGIONALA DE DRUMURI SI PODURI BUCURESTIsocietate pe actiuniBd. Dinicu Golescu nr. 38J40/552/2004160543681RomaniaBucurestiSECTOR 1fals; row: NumarOrdine: 3; Categorie: Universalitati; IdentificareBun: Ipoteca mobiliara NR. 539A din 31.10.2022, fara deposedare asupra universalitatii de bunuri mobile si creante prezente si viitoare, afectate activitatii GARANTULUI STRABENBAU LOGISTIC SRL; DescriereSuplimentara: Incluzand, dar fara a se limita la:  stocuri ( materii prime, materiale, produse in curs de executie, semifabricate, produse finite, marfuri ); drepturi de proprietate intelectuala, industriala sau comerciala; intregul fond de comert destinat sa serveasca exploatarii intreprinderii GARANTULUI; toate creantele prezente si viitoare rezultate din contractele care au fost incheiate si vor fi incheiate de GARANT cu partenerii sai comerciali, toate comenzile, facturile si oricare asemenea documente recunoscute de lege si de practica in materie comerciala din care ar putea rezulta orice alte drepturi de creanta prezente si viitoare, ce se vor afla in orice moment, pe durata ipotecii, in patrimoniul GARANTULUI si/sau in toate spatiile in care sunt depozitate sau localizate de catre GARANT, in vederea garantarii creditului in valoare de 3.160.000 lei plus dobanzile aferente, alte costuri si comisioane, inclusiv cheltuielile de orice fel legate de recuperarea tuturor sumelor datorate si cheltuieli de judecata, precum si cheltuielile legate de executarea silita, astfel cum acesta a fost acordat de CREDITOR IMPRUMUTATULUI prin contractul de credit nr. PC2210091197 cu completarile si modificarile ulterioare.; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Init ...
#
#
# row: RowNo: 18; IdCommand: 21851285; DataDocument: 2022-11-23; Creditors: PF: -PJ: RoCredit IFN Baia Mare sucursala Bucuresti;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: CABINET DE AVOCAT CALIN HERTA; IdentificatorInscriere: 2022-11230833149487-UJD; DescriereBunuri: AlteBunuri: CountCategorie: 2; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 1; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 1; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Creante conf. art. 2389 lit. a) si b) din Codul civil; IdentificareBun: Factura seria STB nr. 20221557 din data de 11.11.2022 in suma de 4.849.544,78 lei scadenta in data de 10.01.2023 emisa de STRABENBAU LOGISTIC SRL pentru C.N.A.I.R. SA PRIN D.R.D.P.  BUCURESTI; DescriereSuplimentara: CONTRACT DE CESIUNE DE CREANTA NR. 580C din 22/11/2022 prin care se cesioneaza creanta in suma de 4.849.544,78  lei provenita din Factura fiscala mai sus mentionata pe care cedentul o are asupra debitorului cedat.; AlteInformatii: Constituitor persoana juridica #1;Tert persoana juridica #COMPANIA NATIONALA DE ADMINISTRARE A INFRASTRUCTURII RUTIERE SA � PRIN DIRECTIA REGIONALA DE DRUMURI SI PODURI BUCURESTIsocietate pe actiuniBd. Dinicu Golescu nr. 38J40/552/2004160543681RomaniaBucurestiSECTOR 1fals; row: NumarOrdine: 2; Categorie: Universalitati; IdentificareBun: Ipoteca mobiliara NR. 580B din 22/11/2022, fara deposedare asupra universalitatii de bunuri mobile si creante prezente si viitoare, afectate activitatii GARANTULUI STRABENBAU LOGISTIC SRL; DescriereSuplimentara: Incluzand, dar fara a se limita la:  stocuri ( materii prime, materiale, produse in curs de executie, semifabricate, produse finite, marfuri ); drepturi de proprietate intelectuala, industriala sau comerciala; intregul fond de comert destinat sa serveasca exploatarii intreprinderii GARANTULUI; toate creantele prezente si viitoare rezultate din contractele care au fost incheiate si vor fi incheiate de GARANT cu partenerii sai comerciali, toate comenzile, facturile si oricare asemenea documente recunoscute de lege si de practica in materie comerciala din care ar putea rezulta orice alte drepturi de creanta prezente si viitoare, ce se vor afla in orice moment, pe durata ipotecii, in patrimoniul GARANTULUI si/sau in toate spatiile in care sunt depozitate sau localizate de catre GARANT, in vederea garantarii creditului in valoare de 3.879.635 lei plus dobanzile aferente, alte costuri si comisioane, inclusiv cheltuielile de orice fel legate de recuperarea tuturor sumelor datorate si cheltuieli de judecata, precum si cheltuielile legate de executarea silita, astfel cum acesta a fost acordat de CREDITOR IMPRUMUTATULUI prin contractul de credit nr. RQ22110303036256 cu completarile si modificarile ulterioare.; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: IN VEDEREA GARANTARII RAMBURSARII CREDITULUI ACORDAT DE ROCREDIT IFN SA BAIA MARE PRI SUCURSALA BUCURESTI IN BAZA CONTRACTULUI DE CREDIT NR. RQ22110303036256 din 22/11/2022 SI ACTELE ADITIONALE LA ACESTA CU EVENTUALELE MODIFICARI ULTERIOARE, PLUS DOBANZILE, COMISOIANELE, TAXELE SI ALTE CHELTUIELI, ETC.
#
#
# row: RowNo: 19; IdCommand: 21851285; DataDocument: 2022-12-06; Creditors: PF: -PJ: RoCredit IFN Baia Mare sucursala Bucuresti;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: CABINET DE AVOCAT CALIN HERTA; IdentificatorInscriere: 2022-12061153309778-MXO; DescriereBunuri: AlteBunuri: CountCategorie: 3; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 3; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Creante conf. art. 2389 lit. a) si b) din Codul civil; IdentificareBun: Contract de cesiune de creanta NR. 1211A din 05/12/2022 a creantelor provenite din CONTRACT SUBSECVENT DE LUCRARI NR.357 din data de 05.09.2022 inregistrat la C.N.A.I.R. SA prin D.R.D.P. BUCURESTI sub nr. 4E/179861 din data de 05.09.2022 incheiat intre CEDENT si DEBITORUL CEDAT,cu actele aditionale prezente si viitoare; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1;Tert persoana juridica #COMPANIA NATIONALA DE ADMINISTRARE A INFRASTRUCTURII RUTIERE SA � PRIN DIRECTIA REGIONALA DE DRUMURI SI PODURI BUCURESTIsocietate pe actiuniBd. Dinicu Golescu nr. 38J40/552/2004160543681RomaniaBucurestiSECTOR 1fals; row: NumarOrdine: 2; Categorie: Creante conf. art. 2389 lit. a) si b) din Codul civil; IdentificareBun: Factura seria STB nr. 20221588 din data de 16.11.2022 in suma de 1.275.991,88 lei scadenta in data de 15.01.2023 emisa de STRABENBAU LOGISTIC SRL pentru C.N.A.I.R. SA PRIN D.R.D.P.  BUCURESTI; DescriereSuplimentara: CONTRACT DE CESIUNE DE CREANTA NR. 1211B din 05/12/2022 prin care se cesioneaza creanta in suma de 3.942.686,85 lei provenita din Factura fiscala mai sus mentionata pe care cedentul o are asupra debitorului cedat.; AlteInformatii: Constituitor persoana juridica #1;Tert persoana juridica #COMPANIA NATIONALA DE ADMINISTRARE A INFRASTRUCTURII RUTIERE SA � PRIN DIRECTIA REGIONALA DE DRUMURI SI PODURI BUCURESTIsocietate pe actiuniBd. Dinicu Golescu nr. 38J40/552/2004160543681RomaniaBucurestiSECTOR 1fals; row: NumarOrdine: 3; Categorie: Creante conf. art. 2389 lit. a) si b) din Codul civil; IdentificareBun: Factura seria STB nr. 20221590 din data de 16.11.2022 in suma de 2.666.694,97 lei scadenta in data de 15.01.2023 emisa de STRABENBAU LOGISTIC SRL pentru C.N.A.I.R. SA PRIN D.R.D.P.  BUCURESTI; DescriereSuplimentara: CONTRACT DE CESIUNE DE CREANTA NR. 1211B din 05/12/2022 prin care se cesioneaza creanta in suma de 3.942.686,85 lei provenita din Factura fiscala mai sus mentionata pe care cedentul o are asupra debitorului cedat.; AlteInformatii: Constituitor persoana juridica #1;Tert persoana juridica #COMPANIA NATIONALA DE ADMINISTRARE A INFRASTRUCTURII RUTIERE SA � PRIN DIRECTIA REGIONALA DE DRUMURI SI PODURI BUCURESTIsocietate pe actiuniBd. Dinicu Golescu nr. 38J40/552/2004160543681RomaniaBucurestiSECTOR 1fals; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune:
#
#
# row: RowNo: 20; IdCommand: 21851285; DataDocument: 2022-12-22; Creditors: PF: -PJ: RoCredit IFN Baia Mare sucursala Bucuresti;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: CABINET DE AVOCAT CALIN HERTA; IdentificatorInscriere: 2022-12221404139748-BTC; DescriereBunuri: AlteBunuri: CountCategorie: 2; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 2; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Creante conf. art. 2389 lit. a) si b) din Codul civil; IdentificareBun: Contract de cesiune de creanta NR. 1330 din 22/12/2022 a creantelor provenite din CONTRACT SUBSECVENT DE LUCRARI NR. 422 din data de 19.10.2022 inregistrat la C.N.A.I.R. SA prin D.R.D.P. BUCURESTI sub nr. 4E/180155 din data de 19.10.2022 incheiat intre CEDENT si DEBITORUL CEDAT, cu actele aditionale prezente si viitoare; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1;Tert persoana juridica #COMPANIA NATIONALA DE ADMINISTRARE A INFRASTRUCTURII RUTIERE SA � PRIN DIRECTIA REGIONALA DE DRUMURI SI PODURI BUCURESTIsocietate pe actiuniBd. Dinicu Golescu nr. 38J40/552/2004160543681RomaniaBucurestiSECTOR 1fals; row: NumarOrdine: 2; Categorie: Creante conf. art. 2389 lit. a) si b) din Codul civil; IdentificareBun: Factura seria STB nr. 20221745 din data de 15-12-2022 in suma de 3.211.215 lei scadenta in data de 14.02.2023 emisa de STRABENBAU LOGISTIC SRL pentru C.N.A.I.R. SA PRIN D.R.D.P.  BUCURESTI; DescriereSuplimentara: CONTRACT DE CESIUNE DE CREANTA NR. 1331 din 22/12/2022 prin care se cesioneaza creanta in suma de 3.211.215 lei provenita din Factura fiscala mai sus mentionata pe care cedentul o are asupra debitorului cedat.; AlteInformatii: Constituitor persoana juridica #1;Tert persoana juridica #COMPANIA NATIONALA DE ADMINISTRARE A INFRASTRUCTURII RUTIERE SA � PRIN DIRECTIA REGIONALA DE DRUMURI SI PODURI BUCURESTIsocietate pe actiuniBd. Dinicu Golescu nr. 38J40/552/2004160543681RomaniaBucurestiSECTOR 1fals; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune:
#
#
# row: RowNo: 21; IdCommand: 21851285; DataDocument: 2023-01-05; Creditors: PF: -PJ: RoCredit IFN Baia Mare sucursala Bucuresti;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: CABINET DE AVOCAT CALIN HERTA; IdentificatorInscriere: 2023-01051209519677-ZXZ; DescriereBunuri: AlteBunuri: CountCategorie: 2; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 1; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 1; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Creante conf. art. 2389 lit. a) si b) din Codul civil; IdentificareBun: Factura seria STB nr. 20221791 din data de 22.12.2022 in suma de 4.624.149,60  lei scadenta in data de 21.02.2023 emisa de STRABENBAU LOGISTIC SRL pentru C.N.A.I.R. SA PRIN D.R.D.P. BUCURESTI; DescriereSuplimentara: CONTRACT DE CESIUNE DE CREANTA NR. 1C din 04/01/2023 prin care se cesioneaza creanta in suma de 4.624.149,60  lei provenita din Factura fiscala mai sus mentionata pe care cedentul o are asupra debitorului cedat.; AlteInformatii: Constituitor persoana juridica #1;Tert persoana juridica #COMPANIA NATIONALA DE ADMINISTRARE A INFRASTRUCTURII RUTIERE SA � PRIN DIRECTIA REGIONALA DE DRUMURI SI PODURI BUCURESTIsocietate pe actiuniBd. Dinicu Golescu nr. 38J40/552/2004160543681RomaniaBucurestiSECTOR 1fals; row: NumarOrdine: 2; Categorie: Universalitati; IdentificareBun: Ipoteca mobiliara NR. 1B din 04/01/2023, fara deposedare asupra universalitatii de bunuri mobile si creante prezente si viitoare, afectate activitatii GARANTULUI STRABENBAU LOGISTIC SRL; DescriereSuplimentara: Incluzand, dar fara a se limita la:  stocuri ( materii prime, materiale, produse in curs de executie, semifabricate, produse finite, marfuri ); drepturi de proprietate intelectuala, industriala sau comerciala; intregul fond de comert destinat sa serveasca exploatarii intreprinderii GARANTULUI; toate creantele prezente si viitoare rezultate din contractele care au fost incheiate si vor fi incheiate de GARANT cu partenerii sai comerciali, toate comenzile, facturile si oricare asemenea documente recunoscute de lege si de practica in materie comerciala din care ar putea rezulta orice alte drepturi de creanta prezente si viitoare, ce se vor afla in orice moment, pe durata ipotecii, in patrimoniul GARANTULUI si/sau in toate spatiile in care sunt depozitate sau localizate de catre GARANT, in vederea garantarii creditului in valoare de 3.930.527 lei plus dobanzile aferente, alte costuri si comisioane, inclusiv cheltuielile de orice fel legate de recuperarea tuturor sumelor datorate si cheltuieli de judecata, precum si cheltuielile legate de executarea silita, astfel cum acesta a fost acordat de CREDITOR IMPRUMUTATULUI prin contractul de credit nr. RQ23010303036323 cu completarile si modificarile ulterioare.; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: IN VEDEREA GARANTARII RAMBURSARII CREDITULUI ACORDAT DE ROCREDIT IFN SA BAIA MARE PRIN SUCURSALA BUCURESTI IN BAZA CONTRACTULUI DE CREDIT NR. RQ23010303036323 din 04/01/2023 SI ACTELE ADITIONALE LA ACESTA CU EVENTUALELE MODIFICARI ULTERIOARE, PLUS DOBANZILE, COMISOIANELE, TAXELE SI ALTE CHELTUIELI, ETC.
#
#
# row: RowNo: 22; IdCommand: 21851285; DataDocument: 2023-01-16; Creditors: PF: -PJ: RoCredit IFN Baia Mare sucursala Bucuresti;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: CABINET DE AVOCAT CALIN HERTA; IdentificatorInscriere: 2023-01161340529986-ZCX; DescriereBunuri: AlteBunuri: CountCategorie: 2; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 1; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 1; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Creante conf. art. 2389 lit. a) si b) din Codul civil; IdentificareBun: Factura seria STB nr. 20221781 din data de 22.12.2022 in suma de 3.481.464,50 lei scadenta in data de 20.02.2023 emisa de STRABENBAU LOGISTIC SRL pentru C.N.A.I.R. SA PRIN D.R.D.P.  BUCURESTI; DescriereSuplimentara: CONTRACT DE CESIUNE DE CREANTA NR. 16C din 13/01/2023 prin care se cesioneaza creanta in suma de 3.481.464,50 lei provenita din Factura fiscala mai sus mentionata pe care cedentul o are asupra debitorului cedat.; AlteInformatii: Constituitor persoana juridica #1;Tert persoana juridica #COMPANIA NATIONALA DE ADMINISTRARE A INFRASTRUCTURII RUTIERE SA � PRIN DIRECTIA REGIONALA DE DRUMURI SI PODURI BUCURESTIsocietate pe actiuniBd. Dinicu Golescu nr. 38J40/552/2004160543681RomaniaBucurestiSECTOR 1fals; row: NumarOrdine: 2; Categorie: Universalitati; IdentificareBun: Ipoteca mobiliara NR. 16B din 13/01/2023, fara deposedare asupra universalitatii de bunuri mobile si creante prezente si viitoare, afectate activitatii GARANTULUI STRABENBAU LOGISTIC SRL; DescriereSuplimentara: Incluzand, dar fara a se limita la:  stocuri ( materii prime, materiale, produse in curs de executie, semifabricate, produse finite, marfuri ); drepturi de proprietate intelectuala, industriala sau comerciala; intregul fond de comert destinat sa serveasca exploatarii intreprinderii GARANTULUI; toate creantele prezente si viitoare rezultate din contractele care au fost incheiate si vor fi incheiate de GARANT cu partenerii sai comerciali, toate comenzile, facturile si oricare asemenea documente recunoscute de lege si de practica in materie comerciala din care ar putea rezulta orice alte drepturi de creanta prezente si viitoare, ce se vor afla in orice moment, pe durata ipotecii, in patrimoniul GARANTULUI si/sau in toate spatiile in care sunt depozitate sau localizate de catre GARANT, in vederea garantarii creditului in valoare de 2.959.244 lei plus dobanzile aferente, alte costuri si comisioane, inclusiv cheltuielile de orice fel legate de recuperarea tuturor sumelor datorate si cheltuieli de judecata, precum si cheltuielile legate de executarea silita, astfel cum acesta a fost acordat de CREDITOR IMPRUMUTATULUI prin contractul de credit nr. RQ23010303036336 cu completarile si modificarile ulterioare.; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: IN VEDEREA GARANTARII RAMBURSARII CREDITULUI ACORDAT DE ROCREDIT IFN SA BAIA MARE PRIN SUCURSALA BUCURESTI IN BAZA CONTRACTULUI DE CREDIT NR. RQ23010303036336 din 13/01/2023 SI ACTELE ADITIONALE LA ACESTA CU EVENTUALELE MODIFICARI ULTERIOARE, PLUS DOBANZILE, COMISOIANELE, TAXELE SI ALTE CHELTUIELI, ETC.
#
#
# row: RowNo: 23; IdCommand: 21851285; DataDocument: 2023-05-29; Creditors: PF: -PJ: EXIM BANCA ROMANEASCA, CENTRUL DE AFACERI PLOIESTI; STATUL ROMAN, REPREZENTAT DE MINISTERUL FINANTELOR, PRIN MANDATAR FONDUL NATIONAL DE GARANTARE A CREDITELOR PENTRU INTREPRINDERILE MICI SI MIJLOCII S.A. - IFN;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: CABINETE ASOCIATE DE AVOCATURA VIDAEFF-NEDELCU; IdentificatorInscriere: 2023-05291044357652-AGK; DescriereBunuri: AlteBunuri: CountCategorie: 1; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 1; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 0; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Cont bancar; IdentificareBun: RO11BRMA0999100090878520; DescriereSuplimentara: CONT CURENT
#     STATUL ROMAN, PRIN MINISTERUL FINANTELOR (M.F.), REPREZENTAT DE FONDUL NATIONAL DE GARANTARE A CREDITELOR PENTRU INTREPRINDERILE MICI SI MIJLOCII - S.A. � IFN (FNGCIMM) ARE CALITATEA DE CO-CREDITOR AL IMPRUMUTATULUI, CU RANG EGAL CU BANCA, PROPORTIONAL CU PROCENTUL DE GARANTARE, SUB CONDITIA PLATII GARANTIEI SI IN LIMITA SUMEI EFECTIV PLATITE BANCII.; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: CONTRACT DE GARANTARE NR. OUG110_66916/26.06.2020 PRIN CARE F.N.G.C.I.M.M. GARANTEAZA IN NUMELE SI IN CONTUL STATULUI, IN MOD DIRECT, EXPRES, IREVOCABIL SI NECONDITIONAT, RAMBURSAREA PROPORTIONALA CU PROCENTUL DE GARANTARE A CREDITULUI IN VALOARE DE 5.000.000 LEI, CARE SE ACORDA PRIN CONTRACTUL DE CREDIT NR. 94094200271/29.06.2020 BENEFICIARULUI STRABENBAU LOGISTIC SRL DE CATRE INSTITUTIA DE CREDIT EXIM BANCA ROMANEASCA SA IN CADRUL PROGRAMULUI DE SUSTINERE A INTREPRINDERILOR MICI SI MIJLOCII � IMM INVEST ROMANIA.
#
#
# row: RowNo: 24; IdCommand: 21851285; DataDocument: 2023-06-22; Creditors: PF: -PJ: STATUL ROMAN, REPREZENTAT DE MINISTERUL FINANTELOR, PRIN MANDATAR FONDUL NATIONAL DE GARANTARE A CREDITELOR PENTRU INTREPRINDERILE MICI SI MIJLOCII SA � IFN; CEC BANK S.A.;; Debitors: PF: -PJ: STRABENBAU LOGISTIC SRL;; UtilizatorAutorizat: AD REGESTA SA - BUCURESTI; IdentificatorInscriere: 2023-06221908567550-JCJ; DescriereBunuri: AlteBunuri: CountCategorie: 2; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 2; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 0; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 0; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Cont bancar; IdentificareBun: RO17CECEB00030RON0584884; DescriereSuplimentara: CONT DESCHIS LA CEC BANK S.A; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 2; Categorie: Cont bancar; IdentificareBun: RO33CECEC001946009256231; DescriereSuplimentara: CONT DESCHIS LA CEC BANK S.A; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Initial; DetaliiComune: IPOTECA LEGALA MOBILIARA ASUPRA SOLDURILOR CREDITOARE ALE TUTUROR CONTURILOR PREZENTE, CAT SI A ORICAROR CONTURI VIITOARE DESCHISE DE BENEFICIARUL PROGRAMULUI LA CEC BANK SA, CONSTITUITA IN FAVOAREA STATULUI ROMAN REPREZENTAT DE MINISTERUL FINANTELOR PRIN FNGCIMM SI CEC BANK S.A. SUCURSALA GARA DE NORD, CUI 39487930, IN NUMELE SI PE SEAMA CEC BANK S.A., IN CALITATE DE COCREDITORI, IN CONFORMITATE CU PREVEDERILE ART.11 DIN OUG 99/2022 CU MODIFICARILE ULTERIOARE, PROPORTIONAL CU PROCENTUL DE GARANTARE, PENTRU GARANTAREA PLATII SI DESCARCAREA IN INTREGIME A OBLIGATIILOR PANA LA CONCURENTA SUMEI PRINCIPALE IMPRUMUTATE IN VALOARE DE 5.000.000 LEI (CINCIMILIOANELEI), PLUS DOBANZILE, DOBANZILE PENALIZATOARE, COSTURILE SI SPEZELE BANCARE AFERENTE PRECUM SI A ORICAROR ALTE SUME DATORATE SAU POTENTIAL DATORATE BANCII IN BAZA CONTRACTULUI DE GARANTARE NR. GCIPLUS_149779 DIN DATA DE 13.06.2023 SI A  CONTRACTULUI DE CREDIT NR. RQ23066120237386 DIN DATA 22.06.2023 (CU MODIFICARILE ULTERIOARE) (�CONTRACTUL DE CREDIT�), INCHEIAT INTRE STRABENBAU LOGISTIC SRL IN CALITATE DE IMPRUMUTAT SI BANCA,  IMPRUMUT ACORDAT IN CADRUL PROGRAMULUI IMM INVEST PLUS, COMPONENTA GARANT CONSTRUCT.
#
#
# ...
#
#
# row: RowNo: 37; IdCommand: 21851285; DataDocument: 2025-06-30; Creditors: PF: -PJ: BANCA ROMANEASCA; STATUL ROMAN REPREZENTAT DE MINISTERUL FINANTELOR PUBLICE PRIN FONDUL NATIONAL DE GARANTARE A CREDITELOR PENTRU INTREPRINDERILE MICI SI MIJLOCII;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: CCIR2 - centrala; IdentificatorInscriere: 2025-06301502572914-OYA; DescriereBunuri: AlteBunuri: CountCategorie: 6; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 0; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 6; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: GREDER CATERPILLAR, MODEL 120 NEXT GEN, SERIE Y9C00304, CONFORM FACTURA PROFORMA NR. S0248, EMISA DE BERGERAT MONNOYEUR S.R.L.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 2; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: FINISOR ASFALT VOGELE S1800-3/5m/BMS, Sn14823279, CONFORM FACTURA PROFORMA NR. 340 , EMISA DE WIRTGEN ROMANIA S.R.L.,; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 3; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM HD+90/VV/KSG SnWGH0H242HAA00708, CONFORM FACTURA PROFORMA NR. S0248, EMISA DE BERGERAT MONNOYEUR S.R.L.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 4; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM H13, SnWGH0H234EHAA00984, CONFORM FACTURA PROFORMA NR. S0248, EMISA DE BERGERAT MONNOYEUR S.R.L.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 5; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM HD13VV, SnGH0H201CHAA05467, CONFORM FACTURA PROFORMA NR. S0248, EMISA DE BERGERAT MONNOYEUR S.R.L.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 6; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: SCHWING Betonpumpe S36X auf Mercedes Benz Acros 2640, 6�4 EURO 6, serie sasiu nr. WDB964014104011934 ,  AN 2019, CONFORM FACTURA NR. 2020-012, emisa de KRAFTEC CONCRETE EQUIPMENT; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Prelungire; DetaliiComune: IPOTECA MOBILIARA ASUPRA BUNULUI, CONSTITUITA CONFORM CONTRACTULUI DE GARANTARE NR. OUG110_66961 DIN DATA DE 26.06.2020 (CU TOATE MODIFICARILE SI COMPLETARILE ULTERIOARE) PROPORTIONAL CU RISCUL ASUMAT DE FIECARE DINTRE ACESTEA, INCHEIAT INTRE STATUL ROMAN REPREZENTAT DE MINISTERUL FINANTELOR PUBLICE PRIN FONDUL NATIONAL DE GARANTARE A CREDITELOR PENTRU INTREPRINDERILE MICI SI MIJLOCII SI BANCA ROMANEASCA S.A. IN CALITATE DE FINANTATOR SI STRABENBAU LOGISTIC S.R.L. IN CALITATE DE BENEFICIAR SI CONSTITUITOR AL ACESTEI IPOTECI LEGALE PENTRU GARANTAREA TUTUROR OBLIGATIILOR IZVORATE DIN CONTRACTUL DE CREDIT NR. 94094200270 DIN 29.06.2020 (CU TOATE MODIFICARILE SI COMPLETARILE ULTERIOARE).
#
#
# row: RowNo: 38; IdCommand: 21851285; DataDocument: 2025-06-30; Creditors: PF: -PJ: BANCA ROMANEASCA; STATUL ROMAN REPREZENTAT DE MINISTERUL FINANTELOR PUBLICE PRIN FONDUL NATIONAL DE GARANTARE A CREDITELOR PENTRU INTREPRINDERILE MICI SI MIJLOCII;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ;; UtilizatorAutorizat: CCIR2 - centrala; IdentificatorInscriere: 2025-06301505072535-MYT; DescriereBunuri: AlteBunuri: CountCategorie: 8; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 0; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 8; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: GREDER CATERPILLAR, Model 120 NEXT GEN seria sasiu Y9C00304, CONFORM FACTURA FISCALA NR. LF126632, EMISA DE BERGERAT MONNOYEUR S.R.L.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 2; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: AUTOBETONIERA MERCEDES BENZ, TIP 4142 SERIA SASIU NMB96433112190406, CONFORM FACTURA FISCALA NR. TBLAT052 , EMISA DE SCHWING STETTER.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 3; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: AUTOBETONIERA MERCEDES BENZ, TIP 4142 SERIA SASIU NMB96433112190488, CONFORM FACTURA FISCALA NR. TBLAT0524, EMISA DE SCHWING STETTER; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 4; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: POMPA DE BETON AUTO MERCEDES BENZ ACTROS 2640, SERIA SASIU WDB96401410401934, CONFORM FACTURA FISCALA NR. 1/06.07.2020, EMISA DE KRAFTECCONCRETE EQUIPMENT; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 5; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: FINISOR ASFALT VOGELE, S1800-3i/5m/BMS, CONFORM FACTURA FISCALA NR. 55348/03.07.2020, EMISA DE WIRTGEN GROUP ROMANIA SR; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 6; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM, HD +90IVV/KSG, CONFORM FACTURA NR. 55348/03.07.2020, emisa de WIRTGEN GROUP ROMANIA SRL; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 7; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM, H13i, CONFORM FACTURA NR. 55348/03.07.2020, emisa de WIRTGEN GROUP ROMANIA SRL; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 8; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM, HD13VV, CONFORM FACTURA NR. 55348/03.07.2020, emisa de WIRTGEN GROUP ROMANIA SRL; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Prelungire; DetaliiComune: IPOTECA MOBILIARA ASUPRA BUNULUI, CONSTITUITA CONFORM CONTRACTULUI DE GARANTARE NR. OUG110_66961 DIN DATA DE 26.06.2020 (CU TOATE MODIFICARILE SI COMPLETARILE ULTERIOARE) PROPORTIONAL CU RISCUL ASUMAT DE FIECARE DINTRE ACESTEA, INCHEIAT INTRE STATUL ...
#
#
# row: RowNo: 39; IdCommand: 21851285; DataDocument: 2025-06-30; Creditors: PF: -PJ: BANCA ROMANEASCA; STATUL ROMAN REPREZENTAT DE MINISTERUL FINANTELOR PUBLICE PRIN FONDUL NATIONAL DE GARANTARE A CREDITELOR PENTRU INTREPRINDERILE MICI SI MIJLOCII;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: CCIR2 - centrala; IdentificatorInscriere: 2025-06301506242271-JAH; DescriereBunuri: AlteBunuri: CountCategorie: 8; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 0; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 8; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: GREDER CATERPILLAR, Model 120 NEXT GEN seria sasiu Y9C00304, CONFORM FACTURA FISCALA NR. LF126632, EMISA DE BERGERAT MONNOYEUR S.R.L.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 2; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: AUTOBETONIERA MERCEDES BENZ, TIP 4142 SERIA SASIU NMB96433112190406, CONFORM FACTURA FISCALA NR. TBLAT052 , EMISA DE SCHWING STETTER; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 3; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: AUTOBETONIERA MERCEDES BENZ, TIP 4142 SERIA SASIU NMB96433112190488, CONFORM FACTURA FISCALA NR. TBLAT0524, EMISA DE SCHWING STETTER; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 4; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: POMPA DE BETON AUTO MERCEDES BENZ ACTROS 2640, SERIA SASIU WDB96401410401934, CONFORM FACTURA FISCALA NR. 1/06.07.2020, EMISA DE KRAFTECCONCRETE EQUIPMENT; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 5; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: FINISOR ASFALT VOGELE, S1800-3i/5m/BMS, CONFORM FACTURA FISCALA NR. 55348/03.07.2020, EMISA DE WIRTGEN GROUP ROMANIA SR; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 6; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM, HD +90IVV/KSG, CONFORM FACTURA NR. 55348/03.07.2020, emisa de WIRTGEN GROUP ROMANIA SRL; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 7; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM, H13i, CONFORM FACTURA NR. 55348/03.07.2020, emisa de WIRTGEN GROUP ROMANIA SRL; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 8; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM, HD13VV, CONFORM FACTURA NR. 55348/03.07.2020, emisa de WIRTGEN GROUP ROMANIA SRL; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Prelungire; DetaliiComune: IPOTECA MOBILIARA ASUPRA BUNULUI, CONSTITUITA CONFORM CONTRACTULUI DE GARANTARE NR. OUG110_66916 DIN DATA DE 26.06.2020 (CU TOATE MODIFICARILE SI COMPLETARILE ULTERIOARE) PROPORTIONAL CU RISCUL ASUMAT DE FIECARE DINTRE ACESTEA, INCHEIAT INTRE STATUL R ...
#
#
# row: RowNo: 40; IdCommand: 21851285; DataDocument: 2025-06-30; Creditors: PF: -PJ: BANCA ROMANEASCA; STATUL ROMAN REPREZENTAT DE MINISTERUL FINANTELOR PUBLICE PRIN FONDUL NATIONAL DE GARANTARE A CREDITELOR PENTRU INTREPRINDERILE MICI SI MIJLOCII;; Debitors: PF: -PJ: STRABENBAU LOGISTIC ;; UtilizatorAutorizat: CCIR2 - centrala; IdentificatorInscriere: 2025-06301509152575-NBG; DescriereBunuri: AlteBunuri: CountCategorie: 6; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 0; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 6; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: GREDER CATERPILLAR, MODEL 120 NEXT GEN, SERIE Y9C00304, CONFORM FACTURA PROFORMA NR. S0248, EMISA DE BERGERAT MONNOYEUR S.R.L.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 2; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: FINISOR ASFALT VOGELE S1800-3/5m/BMS, Sn14823279, CONFORM FACTURA PROFORMA NR. 340 , EMISA DE WIRTGEN ROMANIA S.R.L.,; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 3; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM HD+90/VV/KSG SnWGH0H242HAA00708, CONFORM FACTURA PROFORMA NR. S0248, EMISA DE BERGERAT MONNOYEUR S.R.L.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 4; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM H13, SnWGH0H234EHAA00984, CONFORM FACTURA PROFORMA NR. S0248, EMISA DE BERGERAT MONNOYEUR S.R.L.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 5; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM HD13VV, SnGH0H201CHAA05467, CONFORM FACTURA PROFORMA NR. S0248, EMISA DE BERGERAT MONNOYEUR S.R.L.; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 6; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: SCHWING Betonpumpe S36X auf Mercedes Benz Acros 2640, 6�4 EURO 6, serie sasiu nr. WDB964014104011934 ,  AN 2019, CONFORM FACTURA NR. 2020-012, emisa de KRAFTEC CONCRETE EQUIPMENT; DescriereSuplimentara: ; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Prelungire; DetaliiComune: IPOTECA MOBILIARA ASUPRA BUNULUI, CONSTITUITA CONFORM CONTRACTULUI DE GARANTARE NR.OUG110_66916/26.06.2020 (CU TOATE MODIFICARILE SI COMPLETARILE ULTERIOARE) PROPORTIONAL CU RISCUL ASUMAT DE FIECARE DINTRE ACESTEA, INCHEIAT INTRE STATUL ROMAN REPREZENTAT DE MINISTERUL FINANTELOR PUBLICE PRIN FONDUL NATIONAL DE GARANTARE A CREDITELOR PENTRU INTREPRINDERILE MICI SI MIJLOCII SI BANCA ROMANEASCA S.A. IN CALITATE DE FINANTATOR SI STRABENBAU LOGISTIC S.R.L. IN CALITATE DE BENEFICIAR SI CONSTITUITOR AL ACESTEI IPOTECI LEGALE PENTRU GARANTAREA TUTUROR OBLIGATIILOR IZVORATE DIN CONTRACTUL DE CREDIT NR.94094200271/29.06.2020 (CU TOATE MODIFICARILE SI COMPLETARILE ULTERIOARE).
#
#
# Număr total de elemente (copii ai rădăcinii): 40

# %%
from sentence_transformers import SentenceTransformer, util
import torch

# Load model on GPU
model = SentenceTransformer('intfloat/multilingual-e5-large', device='gpu')

# Suppose you already chunked your documents
texts = contents

# Precompute all text embeddings (do this once)
text_embeddings = model.encode(texts, convert_to_tensor=True, batch_size=32, show_progress_bar=True)

# When a question comes in:
question = "In ce data a fost primita oferta de la KRAFTEC PROFORMA?"
question_embedding = model.encode(question, convert_to_tensor=True)

# Compute cosine similarities
scores = util.cos_sim(question_embedding, text_embeddings)[0]

# Find best match
best_idx = torch.argmax(scores).item()
print(f"Best match: {texts[best_idx]} (Score: {scores[best_idx]:.3f})")
# Out:
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Best match: row: RowNo: 36; IdCommand: 21851285; DataDocument: 2025-06-24; Creditors: PF: -PJ: BANCA ROMANEASCA; STATUL ROMAN REPREZENTAT DE MINISTERUL FINANTELOR PUBLICE PRIN FONDUL NATIONAL DE GARANTARE A CREDITELOR PENTRU INTREPRINDERILE MICI SI MIJLOCII;; Debitors: PF: -PJ: STRABENBAU LOGISTIC;; UtilizatorAutorizat: CCIR2 - centrala; IdentificatorInscriere: 2025-06241456167291-VBQ; DescriereBunuri: AlteBunuri: CountCategorie: 8; Actiuni_parti_sociale_valori_mobiliare_alte_instrumente_financiare: 0; AlteBunuri: 0; ContBancar: 0; Creante_Conf_art_2389_lir_a_si_b_din_Codul_civil: 0; Echipamente_instalatii_alte_bunuri_destinate_sa_serveasca_exploatarii_unei_intreprinderi: 8; EfectiveDeAnimale: 0; InscriereVeche: 0; PoliteDeAsigurare: 0; Recolte: 0; Universalitati: 0; UtilajeAgricoleAlteleDecatAutovehicule: 0; row: NumarOrdine: 1; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: FINISOR ASFALT VOGELE; DescriereSuplimentara: pret Euro fara TVA: 265,000.00
#     Oferta primita: WIRTGEN PROFORMA 340/29.06.2020; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 2; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM HD+90IVV; DescriereSuplimentara: pret Euro fara TVA: 86,000.00
#     Oferta primita: WIRTGEN PROFORMA 340/29.06.2020; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 3; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM H13I; DescriereSuplimentara: pret Euro fara TVA: 84,000.00
#     Oferta primita: WIRTGEN PROFORMA 340/29.06.2020; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 4; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: CILINDRU COMPACTOR HAMM HD13VV; DescriereSuplimentara: pret Euro fara TVA: 35,000.00
#     Oferta primita: WIRTGEN PROFORMA 340/29.06.2020; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 5; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: AUTOBETONIERA STETTER 10MC; DescriereSuplimentara: pret Euro fara TVA: 105,000.00
#     Oferta primita: TUBLROM PROFORMA AT2020-014/17.06.2020; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 6; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: AUTOBETONIERA STETTER 10MC; DescriereSuplimentara: pret Euro fara TVA: 105,000.00
#     Oferta primita: TUBLROM PROFORMA AT2020-014/17.06.2020; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 7; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: POMPA DE BETON S36X; DescriereSuplimentara: pret Euro fara TVA: 336,000.00
#     Oferta primita: KRAFTEC PROFORMA 2020-012/17.06.2020; AlteInformatii: Constituitor persoana juridica #1; row: NumarOrdine: 8; Categorie: Echipamente/instalatii/alte bunuri destinate sa serveasca exploatarii unei intreprinderi; IdentificareBun: GREDER CATERPILLAR; DescriereSuplimentara: pret Euro fara TVA: 290,000.00
#     Oferta primita: BERGERAT PROFORMA S0248/29.06.2020; AlteInformatii: Constituitor persoana juridica #1; DateUpdate: 2025-11-05; FilterDescription: (Numai active) SI (Nemodificate) SI (DEBITOR PJ Cui "33221610""); RecordsFound: 40; TotalLinksNo: 40; TipAviz: Aviz de ipotec? mobiliar? - Aviz Prelungire; DetaliiComune: IPOTECA MOBILIARA ASUPRA UNOR BUNURI VIITOARE, CONSTITUITA CONFORM CONTRACTULUI DE GARANTARE NR. OUG110_66916 DIN DATA DE 26.06.2020 (CU TOATE MODIFICARILE SI COMPLETARILE ULTERIOARE), INCHEIAT INTRE STATUL ROMAN REPREZENTAT DE MINISTERUL FINANTELOR PUBLICE PRIN FONDUL NATIONAL DE GARANTARE A CREDITELOR PENTRU INTREPRINDERILE MICI SI MIJLOCII SI BANCA ROMANEASCA S.A. IN CALITATE DE FINANTATOR SI STRABENBAU LOGISTIC  S.R.L. IN CALITATE DE BENEFICIAR SI CONSTITUITOR AL ACESTEI IPOTECI LEGALE PENTRU GARANTAREA TUTUROR OBLIGATIILOR IZVORATE DIN CONTRACTUL DE CREDIT NR. 94094200271 DIN 29.06.2020 (CU TOATE MODIFICARILE SI COMPLETARILE ULTERIOARE). (Score: 0.828)
